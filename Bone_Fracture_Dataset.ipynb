# %% [markdown]
# # Load a pre-trained YOLOv8n model

# %%
from ultralytics import YOLO
model = YOLO("yolov8n.pt")

# %% [markdown]
# ## Training YOLOv8 on Bone Fracture Dataset

# %%
# !yolo detect train \
data="/home/cas/Documents/Bone-Fracture-1/data.yaml" \
model=yolov8n.pt \
epochs=100\
imgsz=954\
batch=32\
name="bonefracture_train" \
lr0=0.001 lrf=0.01 patience=20
# Out:
# /home/cas/anaconda3/envs/AIOne/lib/python3.12/site-packages/requests/__init__.py:86: RequestsDependencyWarning: Unable to find acceptable character detection dependency (chardet or charset_normalizer).
#   warnings.warn(
# Ultralytics 8.3.203 🚀 Python-3.12.9 torch-2.7.0+cu118 CUDA:0 (NVIDIA GeForce RTX 3090, 24245MiB)
# ...

# %% [markdown]
# ## Validate Trained YOLOv8 Model

# %%
model = YOLO('/home/cas/Documents/runs/detect/bonefracture_train10/weights/best.pt')
model.val()
# Out:
# Ultralytics 8.3.203 🚀 Python-3.12.9 torch-2.7.0+cu118 CUDA:0 (NVIDIA GeForce RTX 3090, 24245MiB)
# Model summary (fused): 72 layers, 3,005,843 parameters, 0 gradients, 8.1 GFLOPs
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 1149.8±418.7 MB/s, size: 15.6 KB)
# val: Scanning /home/cas/Documents/Bone-Fracture-1/valid/labels.cache... 23 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 23/23 149.6Kit/s 0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 3.2it/s 0.6s1.5s
#                    all         23         23      0.997          1      0.995      0.987
# Speed: 4.3ms preprocess, 2.3ms inference, 0.0ms loss, 1.0ms postprocess per image
# Results saved to /home/cas/Documents/runs/detect/val3
# ultralytics.utils.metrics.DetMetrics object with attributes:
#
# ap_class_index: array([0])
# box: ultralytics.utils.metrics.Metric object
# ...

# %% [markdown]
# ## Load Trained YOLOv8 Model for Inference

# %%
from ultralytics import YOLO
infr_model = YOLO("/content/drive/My Drive/runs/runs/detect/bonefracture_train10/weights/best.pt")

# %% [markdown]
# ## Run Inference and Display Result

# %%
results = infr_model("/content/drive/My Drive/Bone-Fracture-1/test/images")
results[43].show()
# Out:
# image 1/53 /content/drive/My Drive/Bone-Fracture-1/Bone-Fracture-1/test/images/fracture-of-the-humeral-capitellum-milch-type-1-1-1-_jpg.rf.a2651e72143b65e1a2495f6b6ffa4a72.jpg: 960x960 1 fracture, 12.2ms
# image 2/53 /content/drive/My Drive/Bone-Fracture-1/Bone-Fracture-1/test/images/image1_1150_png_jpg.rf.bc25480ad2833416a0d1ce6f0e86e471.jpg: 960x960 1 fracture, 12.0ms
# image 3/53 /content/drive/My Drive/Bone-Fracture-1/Bone-Fracture-1/test/images/image1_1159_png_jpg.rf.85332ad59d8202f52330bb0bd9d95676.jpg: 960x960 1 fracture, 12.1ms
# image 4/53 /content/drive/My Drive/Bone-Fracture-1/Bone-Fracture-1/test/images/image1_1190_png_jpg.rf.57dae422bf4e9c96bb6014ffd083316d.jpg: 960x960 1 fracture, 12.1ms
# image 5/53 /content/drive/My Drive/Bone-Fracture-1/Bone-Fracture-1/test/images/image1_1211_png_jpg.rf.2064a439be4ef1e439804fa81291bdc6.jpg: 960x960 1 fracture, 12.1ms
# ...

# %% [markdown]
# ## Upload and Test Image in Google Colab

# %%
from google.colab import files
from PIL import Image
import os

uploaded = files.upload()
for filename in uploaded.keys():
    if filename.endswith('.jfif'):
        image = Image.open(filename)
        new_filename = filename.replace('.jfif', '.jpg')
        image.save(new_filename, 'JPEG')
        filename = new_filename

    results = infr_model(filename)
    results[0].show()
# Out:
#      <input type="file" id="files-c641a36f-4aa2-445d-8fbf-ee0e2050149b" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-c641a36f-4aa2-445d-8fbf-ee0e2050149b">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...
